# %%
# General notebook settings
# %matplotlib inline

# %%
from samples import samples
from scalcs import popen

# %% [markdown]
# ##### $P_{open}$ curve

# %%
mec = samples.CH82()
tres = 0.0001 # 10 us

# %%
popen_analysis = popen.PopenCurve(mec)
print(popen_analysis.printout(tres=tres))
# Out:
# ******************
# Ideal Popen curve:
# Is Monotonic: True
# Trend: ascending
# maximal Popen = 0.9677394380085494
# EC50 = 2.4080276489257817 uM
# Hill slope (nH) = 1.891852810093832
#
# ****************
# HJC Popen curve:
# Is Monotonic: True
# Trend: ascending
# maximal Popen = 0.961847920017044
# EC50 = 2.360343933105469 uM
# Hill slope (nH) = 1.9050537071553801

# %%
#popen.plot_popen_curve(mec, tres)
popen_analysis.plot_popen_curve(cmin=0.1e-6, cmax=0.1e-3, tres=tres)
